# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# data files
az_data = "arizona_sample.csv"
ca_data = "california_sample.csv"

# Read the data
arizona = pd.read_csv(az_data)
california = pd.read_csv(ca_data)

# Display the data table for preview
arizona
# Out:
#        Unnamed: 0         ID  Severity           Start_Time  Start_Lat  \
# 0          986782   A-986783         2  2021-10-13 14:23:30  33.887293
# 1         1516753  A-1516754         2  2021-02-08 16:29:30  33.851682
# 2         1339108  A-1339109         2  2021-02-28 13:25:30  38.589526
# 3         2676590  A-2676591         2  2018-03-13 15:22:57  37.711040
# 4         2336691  A-2336692         2  2020-02-11 06:05:00  34.129727
# ...           ...        ...       ...                  ...        ...
# 99995      806588   A-806589         2  2021-10-12 06:23:30  34.040970
# 99996     2419922  A-2419923         2  2019-10-16 14:40:00  37.695457
# 99997      877256   A-877257         2  2021-10-25 17:26:00  32.764287
# 99998      671874   A-671875         2  2021-10-29 12:38:00  33.837043
# 99999     1713989  A-1713990         2  2021-02-18 17:05:00  34.340890
#
#         Start_Lng                                        Description  \
# ...
