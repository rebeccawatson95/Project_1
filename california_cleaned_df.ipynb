# %%
#import dependencies
import pandas as pd
import numpy as np

# %%
csv_file = "/Users/Jerry/Documents/US_Accidents_Dec21_updated.csv"
accidents_df = pd.read_csv(csv_file)

# %%
#A data frame with only CA and AZ data
cal_ari = accidents_df.loc[(accidents_df["State"] == "CA") |
                          (accidents_df["State"] == "AZ"), :]

# %%
#cal_ari.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
#Unnecessary Columns
#End_Time, End_Lat, End_Lng, Airport_Code, Side, Nautical_Twilight, 
#Astronomical_Twilight, Civil_Twilight
#Amenity, Number, Street, Bump, Give_Way, Railway, Roundabout, Turning_Loop, Traffic_Calming
# Out:
# 988    2016-03-23 00:53:11
# 989    2016-03-23 01:00:49
# 990    2016-03-23 02:07:32
# 991    2016-03-23 03:40:18
# 992    2016-03-23 03:36:42
# Name: End_Time, dtype: object

# %%
#Our data frame with only CA data
cali_df = accidents_df.loc[(accidents_df["State"] == "CA"), :]

# %%
cleaned_df = cali_df[['ID', 'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'Description',
                      'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
                      'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
                      'Pressure(in)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)', 
                      'Precipitation(in)', 'Weather_Condition', 'Crossing', 'Junction', 
                      'No_Exit', 'Station', 'Stop', 'Traffic_Signal', 'Sunrise_Sunset']]

# %%
#Our Main df with only CA data and neccessary columns
cleaned_df.head()
# Out:
#         ID  Severity           Start_Time  Start_Lat   Start_Lng  \
# 988  A-989         3  2016-03-22 18:53:11  38.825840 -120.029214
# 989  A-990         2  2016-03-22 19:00:49  37.358209 -121.840017
# 990  A-991         3  2016-03-22 20:07:32  37.881943 -122.307987
# 991  A-992         2  2016-03-22 21:40:18  37.881038 -122.307788
# 992  A-993         2  2016-03-22 21:36:42  38.518811 -121.101664
#
#                                            Description         City  \
# 988  Between Twin Bridges Tract and South Lake Taho...    Echo Lake
# 989  Between Capitol Expy and Alum Rock Ave - Accid...     San Jose
# 990           At I-80/I-580 Northern Split - Accident.     Berkeley
# 991           At I-80/I-580 Northern Split - Accident.     Berkeley
# 992  Between Latrobe Rd/Indio Dr and Latrobe Rd - A...  Sloughhouse
#
#           County State     Zipcode  ... Wind_Speed(mph) Precipitation(in)  \
# 988    El Dorado    CA       95721  ...             NaN               NaN
# 989  Santa Clara    CA       95116  ...            17.3               NaN
# 990      Alameda    CA       94710  ...             8.1               NaN
# 991      Alameda    CA       94710  ...             8.1               NaN
# 992   Sacramento    CA  95683-9709  ...             3.5               NaN
#
#     Weather_Condition  Crossing  Junction  No_Exit  Station   Stop  \
# 988             Clear     False     False    False    False  False
# 989  Scattered Clouds     False     False    False    False  False
# 990     Partly Cloudy     False      True    False    False  False
# 991             Clear     False     False    False    False  False
# 992             Clear     False     False    False    False  False
#
#     Traffic_Signal  Sunrise_Sunset
# 988          False             Day
# 989          False             Day
# 990          False           Night
# 991          False           Night
# 992          False           Night
#
# [5 rows x 29 columns]

# %%
# %history -g -f notebook_file.ipynb

# %%
#10 days before late oct early nov
#10 days after late feb early march
cleaned_df[["date", "time"]] = cleaned_df["Start_Time"].str.split(" ", expand = True)
cleaned_df[["year", "month", "day"]] = cleaned_df["date"].str.split("-", expand = True)
cleaned_df[["year", "month", "day"]] = cleaned_df[["year", "month", "day"]].astype(int)
cleaned_df.head()
# Out:
# /Users/Jerry/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#         ID  Severity           Start_Time  Start_Lat   Start_Lng  \
# 988  A-989         3  2016-03-22 18:53:11  38.825840 -120.029214
# 989  A-990         2  2016-03-22 19:00:49  37.358209 -121.840017
# 990  A-991         3  2016-03-22 20:07:32  37.881943 -122.307987
# 991  A-992         2  2016-03-22 21:40:18  37.881038 -122.307788
# 992  A-993         2  2016-03-22 21:36:42  38.518811 -121.101664
#
#                                            Description         City  \
# 988  Between Twin Bridges Tract and South Lake Taho...    Echo Lake
# 989  Between Capitol Expy and Alum Rock Ave - Accid...     San Jose
# 990           At I-80/I-580 Northern Split - Accident.     Berkeley
# 991           At I-80/I-580 Northern Split - Accident.     Berkeley
# 992  Between Latrobe Rd/Indio Dr and Latrobe Rd - A...  Sloughhouse
#
#           County State     Zipcode  ... No_Exit Station   Stop  \
# 988    El Dorado    CA       95721  ...   False   False  False
# 989  Santa Clara    CA       95116  ...   False   False  False
# 990      Alameda    CA       94710  ...   False   False  False
# 991      Alameda    CA       94710  ...   False   False  False
# 992   Sacramento    CA  95683-9709  ...   False   False  False
#
#      Traffic_Signal  Sunrise_Sunset        date      time  year month  day
# 988           False             Day  2016-03-22  18:53:11  2016     3   22
# 989           False             Day  2016-03-22  19:00:49  2016     3   22
# 990           False           Night  2016-03-22  20:07:32  2016     3   22
# 991           False           Night  2016-03-22  21:40:18  2016     3   22
# 992           False           Night  2016-03-22  21:36:42  2016     3   22
#
# [5 rows x 34 columns]

# %%
#Filter Data for months involved with Day Light Savings
final_df = cleaned_df.loc[(cleaned_df["month"] == 2) | 
               (cleaned_df["month"] == 3) |
               (cleaned_df["month"] == 10) |
              (cleaned_df["month"] == 11), :]

# %%
#Check len of final df
#Df is to large to upload to github so we will create a new df with a smaller random sample.
#len(final_df)
# Out:
# 286477

# %%
#Random sample for project use
sample_df = final_df.sample(n = 100000)

# %%
#Check length. MB size is good for upload to github
#len(sample_df)
# Out:
# 100000

# %%
#check df 
#sample_df.head()
# Out:
#                 ID  Severity           Start_Time  Start_Lat   Start_Lng  \
# 1901925  A-1901926         2  2020-11-17 17:12:00  39.930742 -123.763228
# 351751    A-351752         2  2021-03-26 13:56:24  34.021157 -118.477548
# 1991543  A-1991544         2  2020-10-29 12:15:30  34.199362 -118.396519
# 1744181  A-1744182         2  2020-11-06 18:15:30  36.684873 -119.749592
# 1612021  A-1612022         2  2021-02-27 11:21:00  39.796584 -123.266931
#
#                                                Description             City  \
# 1901925  Incident on US-101 NB near HOUSE 10069 Expect ...           Piercy
# 351751   Stationary traffic on I-10 W - Santa Monica Fw...     Santa Monica
# 1991543  Stationary traffic from Vose St to CA-170 N du...  North Hollywood
# 1744181  Slow traffic on CA-99 from Central Ave (CA-99)...           Fresno
# 1612021     Accident from Tabor Ln to Tabor Ln / Pomo Trl.           Covelo
#
#               County State     Zipcode  ... No_Exit Station   Stop  \
# 1901925    Mendocino    CA       95587  ...   False   False  False
# 351751   Los Angeles    CA       90404  ...   False   False  False
# 1991543  Los Angeles    CA  91605-5739  ...   False   False  False
# 1744181       Fresno    CA       93725  ...   False   False  False
# 1612021    Mendocino    CA  95428-9749  ...   False   False  False
#
#          Traffic_Signal  Sunrise_Sunset        date      time  year month  day
# 1901925           False           Night  2020-11-17  17:12:00  2020    11   17
# 351751            False             Day  2021-03-26  13:56:24  2021     3   26
# 1991543           False             Day  2020-10-29  12:15:30  2020    10   29
# 1744181           False           Night  2020-11-06  18:15:30  2020    11    6
# 1612021           False             Day  2021-02-27  11:21:00  2021     2   27
#
# [5 rows x 34 columns]

# %%
#Convert dataframe to csv file for upload to github
sample_df.to_csv("california_sample.csv")

# %%
#Arizona Dataframe
#Filter out unnecessary columns
#filter only for Arizona data
start_df = accidents_df.loc[(accidents_df["State"] == "AZ"), :]
ari_df = start_df[['ID', 'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'Description',
                      'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
                      'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
                      'Pressure(in)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)', 
                      'Precipitation(in)', 'Weather_Condition', 'Crossing', 'Junction', 
                      'No_Exit', 'Station', 'Stop', 'Traffic_Signal', 'Sunrise_Sunset']]

# %%
#Create a new columns for data and time to be spilt up
#10 days before late oct early nov
#10 days after late feb early march
ari_df[["date", "time"]] = ari_df["Start_Time"].str.split(" ", expand = True)
ari_df[["year", "month", "day"]] = ari_df["date"].str.split("-", expand = True)
ari_df[["year", "month", "day"]] = ari_df[["year", "month", "day"]].astype(int)
ari_df.head()
# Out:
# /Users/Jerry/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#             ID  Severity           Start_Time  Start_Lat  Start_Lng  \
# 91178  A-91179         4  2016-11-30 13:35:51  34.875803 -114.59780
# 91179  A-91180         3  2016-11-30 15:01:56  33.662770 -111.99958
# 91180  A-91181         2  2016-11-30 15:19:52  33.668760 -112.07275
# 91181  A-91182         2  2016-11-30 15:39:50  33.385630 -111.95325
# 91182  A-91183         2  2016-11-30 17:05:39  33.484250 -112.11319
#
#                                              Description           City  \
# 91178  Closed at CR-153/Boundary Cone Rd/Soatman Rd -...  Mohave Valley
# 91179                 At AZ-101-LOOP/Exit 15 - Accident.        Phoenix
# 91180                      At 7th St/Exit 26 - Accident.        Phoenix
# 91181                  At Priest Dr/Exit 172 - Accident.          Tempe
# 91182                  At Thomas Rd/Exit 201 - Accident.        Phoenix
#
#          County State Zipcode  ... No_Exit Station   Stop  Traffic_Signal  \
# 91178    Mohave    AZ   86440  ...   False   False  False           False
# 91179  Maricopa    AZ   85050  ...   False   False  False           False
# 91180  Maricopa    AZ   85024  ...   False   False  False           False
# 91181  Maricopa    AZ   85282  ...   False   False  False           False
# 91182  Maricopa    AZ   85015  ...   False   False  False           False
#
#        Sunrise_Sunset        date      time  year month  day
# 91178             Day  2016-11-30  13:35:51  2016    11   30
# 91179             Day  2016-11-30  15:01:56  2016    11   30
# 91180             Day  2016-11-30  15:19:52  2016    11   30
# 91181             Day  2016-11-30  15:39:50  2016    11   30
# 91182             Day  2016-11-30  17:05:39  2016    11   30
#
# [5 rows x 34 columns]

# %%
#Filter Data for months involved with Day Light Savings
arizona_df = ari_df.loc[(ari_df["month"] == 2) | 
               (ari_df["month"] == 3) |
               (ari_df["month"] == 10) |
              (ari_df["month"] == 11), :]

# %%
len(arizona_df)
# Out:
# 18506

# %%
#Random sample for project use
arizona_sample_df = arizona_df.sample(n = 18506)

# %%
#Convert dataframe to csv file for upload to github
arizona_sample_df.to_csv("arizona_sample.csv")
